# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
# For GARCH
from arch import arch_model

# For statistical tests
from statsmodels.stats.diagnostic import acorr_ljungbox
from scipy.stats import rankdata, t, norm

# Copula from sklarpy
from copulae import GaussianCopula, StudentCopula, ClaytonCopula, GumbelCopula

csv_file = 'Diversified_Portfolio_Data_Complete.csv'

# Read CSV, parse 'Date' as a datetime, set it as the index
df_prices = pd.read_csv(csv_file, parse_dates=['Date'], index_col='Date')

# Compute daily (simple) returns, drop the first NaN row
df_returns = df_prices.pct_change().dropna()

# Optionally, you could compute log-returns:
# df_returns = np.log(df_prices).diff().dropna()

# Number of assets is just the number of columns (Tron, Solana, etc.)
assets = df_returns.columns
n_assets = len(assets)

print("Loaded price data with shape:", df_prices.shape)
print("Computed daily returns with shape:", df_returns.shape)

###############################################################################
# HELPER FUNCTIONS FOR GARCH FITTING & DIAGNOSTICS
###############################################################################

def fit_garch_models(returns_series, dist_candidates=('normal', 'StudentsT', 'skewt')):
    """
    Fit multiple GARCH(1,1) models (with different distributions) to a single asset.
    Returns the best model (lowest AIC).
    """
    best_model = None
    best_aic = np.inf
    for dist in dist_candidates:
        try:
            am = arch_model(returns_series, vol='GARCH', p=1, o=0, q=1, dist=dist, rescale=True)
            res = am.fit(disp='off')
            if res.aic < best_aic:
                best_aic = res.aic
                best_model = res
        except Exception as e:
            print(f"Warning: Could not fit dist={dist} -> {e}")
            continue
    return best_model

def ljung_box_tests(std_resids, lags=10):
    """
    Ljung-Box tests on standardized residuals (raw & squared).
    Returns a dict with p-values.
    """
    std_resids = std_resids.dropna()
    # Ljung-Box on raw standardized residuals
    lb_raw = acorr_ljungbox(std_resids, lags=[lags], return_df=True)
    pval_raw = lb_raw['lb_pvalue'].iloc[-1]

    # Ljung-Box on squared standardized residuals
    lb_sq = acorr_ljungbox(std_resids**2, lags=[lags], return_df=True)
    pval_sq = lb_sq['lb_pvalue'].iloc[-1]

    return {
        'LjungBox_pval_raw': pval_raw,
        'LjungBox_pval_sq': pval_sq
    }

def to_uniform(series):
    """
    Convert data to pseudo-uniform [0,1] via rank transformation (empirical CDF).
    """
    ranks = rankdata(series, method='ordinal')
    return (ranks - 0.5) / len(series)
# Out:
# Loaded price data with shape: (1561, 9)
# Computed daily returns with shape: (1560, 9)

# %%
###############################################################################
# 1) ROLLING WINDOW DEMO FOR GARCH FITTING
###############################################################################

window_size = 500  # Rolling window size

vol_forecasts = pd.DataFrame(index=df_returns.index, columns=df_returns.columns)
std_resids_full = pd.DataFrame(index=df_returns.index, columns=df_returns.columns)
chosen_models = {}

for asset in df_returns.columns:
    for t in tqdm(range(window_size, len(df_returns)), desc=f"Fitting GARCH of asset {asset}"):
        train_data = df_returns[asset].iloc[t - window_size:t]
        
        # Fit best GARCH model
        best_fit = fit_garch_models(train_data.dropna())
        if best_fit is None:
            continue
        
        chosen_models[(asset, t)] = best_fit
        
        # 1-step ahead variance forecast
        forecast_obj = best_fit.forecast(horizon=1, start=train_data.index[-1])
        var_forecast = forecast_obj.variance.iloc[-1]['h.1']
        
        # Store forecasted volatility
        vol_forecasts.loc[df_returns.index[t], asset] = np.sqrt(var_forecast)
        
        # Store in-sample standardized residuals
        insample_std_res = best_fit.resid / best_fit.conditional_volatility
        std_resids_full.loc[:df_returns.index[t-1], asset] = insample_std_res
# Out:
# Fitting GARCH of asset Tron:   0%|          | 0/1060 [00:00<?, ?it/s]
# Fitting GARCH of asset Tron: 100%|██████████| 1060/1060 [02:46<00:00,  6.36it/s]
# Fitting GARCH of asset Solana: 100%|██████████| 1060/1060 [02:40<00:00,  6.61it/s]
# Fitting GARCH of asset Avalanche: 100%|██████████| 1060/1060 [02:37<00:00,  6.71it/s]
# Fitting GARCH of asset Xrp: 100%|██████████| 1060/1060 [03:16<00:00,  5.40it/s]
# Fitting GARCH of asset Bnb: 100%|██████████| 1060/1060 [02:59<00:00,  5.92it/s]
# Fitting GARCH of asset Bitcoin:  98%|█████████▊| 1044/1060 [03:58<00:04,  3.34it/s]c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# Fitting GARCH of asset Bitcoin: 100%|██████████| 1060/1060 [04:03<00:00,  4.35it/s]
# Fitting GARCH of asset Doge: 100%|██████████| 1060/1060 [03:18<00:00,  5.33it/s]
# Fitting GARCH of asset Etherium: 100%|██████████| 1060/1060 [03:31<00:00,  5.01it/s]
# Fitting GARCH of asset PolkaDot: 100%|██████████| 1060/1060 [02:44<00:00,  6.43it/s]

# %%
# Drop NaN values from standardized residuals before rolling copula fitting
std_resids_full = std_resids_full.dropna()
vol_forecasts = vol_forecasts.dropna()

# %%
std_resids_full
# Out:
#                 Tron    Solana Avalanche       Xrp       Bnb   Bitcoin  \
# Date
# 2023-08-18   0.08527 -0.663939  0.716214 -0.080372 -0.807827 -1.431468
# 2023-08-19  0.758721  0.604592  -0.08011  1.045981  0.171048 -0.066543
# 2023-08-20  1.269808 -0.286197  0.143924  1.227743 -0.194349  0.029991
# 2023-08-21 -0.611494 -0.907221  -2.03214  -0.72302 -1.828229 -0.297831
# 2023-08-22  0.099808 -1.033179 -0.924795  -0.18647 -0.027659 -0.353534
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-25  0.144952 -0.055072 -0.419437 -0.344391  0.185561  0.099591
# 2024-12-26 -0.880353 -1.203642 -1.258643 -1.956411 -0.611074 -1.164416
# 2024-12-27  0.879024 -0.640705 -0.391866 -0.115828  0.046609 -0.606194
# 2024-12-28 -0.264495  1.293905  0.495143  0.460494  1.274521  0.229937
# 2024-12-29   -0.2304 -0.716379  -0.87179 -1.158786 -1.144336 -0.614597
#
#                 Doge  Etherium  PolkaDot
# Date
# 2023-08-18  1.860801 -0.889693  0.853421
# 2023-08-19    0.3338  0.248473  0.053973
# 2023-08-20 -0.038834  0.481145  0.016961
# 2023-08-21 -1.211036 -0.645457 -0.946365
# 2023-08-22 -0.038691 -1.180846 -0.144435
# ...              ...       ...       ...
# 2024-12-25 -0.181111 -0.013333 -0.148757
# 2024-12-26 -1.339104 -1.187864 -1.406751
# 2024-12-27  -0.10954 -0.039281 -0.080757
# 2024-12-28  0.786052  0.498893  0.560523
# 2024-12-29 -0.635301 -0.379619 -0.673615
#
# [500 rows x 9 columns]

# %%
###############################################################################
# 1) ROLLING/EXPANDING WINDOW DEMO
#    - We'll do a simplified "expanding window" from day=0 to day=t-1 for each t.
###############################################################################

initial_train_size = 800

vol_forecasts = pd.DataFrame(index=df_returns.index, columns=df_returns.columns)
std_resids_full = pd.DataFrame(index=df_returns.index, columns=df_returns.columns)
chosen_models = {}

for asset in df_returns.columns:
    for t in range(initial_train_size, len(df_returns)):
        train_data = df_returns[asset].iloc[:t]
        
        # Fit best GARCH model
        best_fit = fit_garch_models(train_data.dropna())
        if best_fit is None:
            continue
        
        chosen_models[(asset, t)] = best_fit
        
        # 1-step ahead variance forecast
        forecast_obj = best_fit.forecast(horizon=1, start=train_data.index[-1])
        var_forecast = forecast_obj.variance.iloc[-1]['h.1']
        
        # Store forecasted volatility
        vol_forecasts.loc[df_returns.index[t], asset] = np.sqrt(var_forecast)
        
        # Store in-sample standardized residuals
        insample_std_res = best_fit.resid / best_fit.conditional_volatility
        std_resids_full.loc[:df_returns.index[t-1], asset] = insample_std_res
# Out:
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ...
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(

# %%
last_day_idx = len(df_returns) - 1  # the final day index
for asset in assets:
    best_fit = chosen_models.get((asset, last_day_idx), None)
    if best_fit:
        # Standardized residuals
        stdres = best_fit.resid / best_fit.conditional_volatility
        
        # Ljung-Box test on residuals
        lb_results = ljung_box_tests(stdres.dropna(), lags=10)
        
        # Print diagnostics (excluding the unavailable 'dist' attribute)
        print(f"[{asset}] AIC={best_fit.aic:.2f}, "
              f"LjungBox pval raw={lb_results['LjungBox_pval_raw']:.3f}, "
              f"LjungBox pval sq={lb_results['LjungBox_pval_sq']:.3f}")
    else:
        print(f"[{asset}] - No final model found.")
# Out:
# [Tron] AIC=-257.84, LjungBox pval raw=0.755, LjungBox pval sq=1.000
# [Solana] AIC=604.59, LjungBox pval raw=0.958, LjungBox pval sq=0.463
# [Avalanche] AIC=645.75, LjungBox pval raw=0.322, LjungBox pval sq=0.152
# [Xrp] AIC=225.27, LjungBox pval raw=0.347, LjungBox pval sq=0.368
# [Bnb] AIC=2356.07, LjungBox pval raw=0.923, LjungBox pval sq=0.002
# [Bitcoin] AIC=2317.89, LjungBox pval raw=0.658, LjungBox pval sq=0.640
# [Doge] AIC=505.31, LjungBox pval raw=0.481, LjungBox pval sq=0.500
# [Etherium] AIC=2470.62, LjungBox pval raw=0.830, LjungBox pval sq=0.833
# [PolkaDot] AIC=434.10, LjungBox pval raw=0.440, LjungBox pval sq=0.917

# %%
print(std_resids_full)
# Out:
#                 Tron    Solana Avalanche       Xrp       Bnb   Bitcoin  \
# Date
# 2023-08-18   0.08527 -0.663939  0.716214 -0.080372 -0.807827 -1.431468
# 2023-08-19  0.758721  0.604592  -0.08011  1.045981  0.171048 -0.066543
# 2023-08-20  1.269808 -0.286197  0.143924  1.227743 -0.194349  0.029991
# 2023-08-21 -0.611494 -0.907221  -2.03214  -0.72302 -1.828229 -0.297831
# 2023-08-22  0.099808 -1.033179 -0.924795  -0.18647 -0.027659 -0.353534
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-25  0.144952 -0.055072 -0.419437 -0.344391  0.185561  0.099591
# 2024-12-26 -0.880353 -1.203642 -1.258643 -1.956411 -0.611074 -1.164416
# 2024-12-27  0.879024 -0.640705 -0.391866 -0.115828  0.046609 -0.606194
# 2024-12-28 -0.264495  1.293905  0.495143  0.460494  1.274521  0.229937
# 2024-12-29   -0.2304 -0.716379  -0.87179 -1.158786 -1.144336 -0.614597
#
#                 Doge  Etherium  PolkaDot
# Date
# 2023-08-18  1.860801 -0.889693  0.853421
# 2023-08-19    0.3338  0.248473  0.053973
# 2023-08-20 -0.038834  0.481145  0.016961
# 2023-08-21 -1.211036 -0.645457 -0.946365
# 2023-08-22 -0.038691 -1.180846 -0.144435
# ...              ...       ...       ...
# 2024-12-25 -0.181111 -0.013333 -0.148757
# 2024-12-26 -1.339104 -1.187864 -1.406751
# 2024-12-27  -0.10954 -0.039281 -0.080757
# 2024-12-28  0.786052  0.498893  0.560523
# 2024-12-29 -0.635301 -0.379619 -0.673615
#
# [500 rows x 9 columns]

# %%
len(copula.params.rho)
# Out:
# 36

# %%
###############################################################################
# 2) ROLLING WINDOW DEMO FOR COPULA FITTING
###############################################################################

copula_candidates = {
    'Gaussian': GaussianCopula,
    'Student-t': StudentCopula,
    'Clayton': ClaytonCopula,
    'Gumbel': GumbelCopula
}

copula_results = {}
rolling_window_size = 100  # Same rolling window size for copula fitting

for t in tqdm(range(rolling_window_size, len(std_resids_full)), desc="Fitting copulas"):
    rolling_data = std_resids_full.iloc[t - rolling_window_size:t].dropna()

    # Check if enough data exists to fit the copula
    if rolling_data.shape[0] <= rolling_data.shape[1]:  # Not enough rows
        print(f"Skipping window at t={t} due to insufficient data")
        continue

    # Convert to pseudo-observations
    u_data = rolling_data.apply(lambda col: to_uniform(col), axis=0)

    best_copula = None
    best_aic = np.inf

    for copula_name, copula_class in copula_candidates.items():
        try:
            copula = copula_class(dim=u_data.shape[1])
            copula.fit(u_data.values)

            # Compute Negative Log-Likelihood (NLL)
            nll = -copula.pdf(u_data.values).sum()

            # Safely calculate the number of parameters
            if copula_name == 'Student-t':
                num_params = len(copula.params[1]) + 1  # Add 1 for degrees of freedom
            elif copula_name == 'Gaussian':
                num_params = len(copula.params)  # Directly an array
            else:  # Clayton or Gumbel (scalar parameter)
                num_params = 1
                
            # Compute AIC: AIC = 2 * num_params + 2 * NLL
            aic = 2 * num_params + 2 * nll

            if aic < best_aic:
                best_aic = aic
                best_copula = (copula_name, copula)

        except Exception as e:
            print(f"Warning: Could not fit {copula_name} copula -> {e}")
            continue

    if best_copula is not None:
        copula_results[t] = best_copula


###############################################################################
# 3) DISPLAY BEST COPULA PER ROLLING WINDOW
###############################################################################

print("\nBest Copula Models for Each Rolling Window:")
for t, (copula_name, copula) in copula_results.items():
    print(f"Window ending at {df_returns.index[t]}: {copula_name} Copula with AIC={best_aic:.2f}")
# Out:
# Fitting copulas: 100%|██████████| 400/400 [1:35:08<00:00, 14.27s/it]
# Best Copula Models for Each Rolling Window:
# Window ending at 2021-01-01 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-01-02 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-01-03 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-01-04 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-01-05 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-01-06 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-01-07 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-01-08 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-01-09 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-01-10 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-01-11 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-01-12 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-01-13 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-01-14 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-01-15 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-01-16 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-01-17 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-01-18 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-01-19 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-01-20 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-01-21 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-01-22 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-01-23 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-01-24 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-01-25 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-01-26 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-01-27 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-01-28 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-01-29 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-01-30 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-01-31 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-02-01 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-02-02 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-02-03 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-02-04 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-02-05 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-02-06 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-02-07 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-02-08 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-02-09 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-02-10 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-02-11 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-02-12 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-02-13 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-02-14 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-02-15 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-02-16 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-02-17 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-02-18 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-02-19 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-02-20 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-02-21 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-02-22 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-02-23 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-02-24 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-02-25 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-02-26 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-02-27 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-02-28 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-03-01 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-03-02 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-03-03 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-03-04 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-03-05 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-03-06 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-03-07 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-03-08 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-03-09 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-03-10 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-03-11 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-03-12 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-03-13 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-03-14 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-03-15 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-03-16 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-03-17 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-03-18 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-03-19 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-03-20 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-03-21 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-03-22 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-03-23 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-03-24 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-03-25 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-03-26 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-03-27 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-03-28 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-03-29 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-03-30 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-03-31 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-01 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-04-02 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-04-03 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-04-04 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-04-05 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-04-06 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-04-07 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-08 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-09 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-10 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-11 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-12 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-13 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-14 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-15 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-16 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-17 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-18 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-19 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-20 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-21 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-22 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-23 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-24 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-25 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-04-26 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-04-27 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-04-28 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-04-29 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-04-30 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-01 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-02 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-03 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-04 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-05 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-06 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-07 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-08 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-09 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-10 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-11 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-12 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-13 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-14 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-15 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-16 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-17 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-18 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-19 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-20 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-21 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-22 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-23 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-24 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-25 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-26 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-27 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-28 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-05-29 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-05-30 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-05-31 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-06-01 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-06-02 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-06-03 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-06-04 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-06-05 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-06-06 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-07 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-08 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-09 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-10 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-11 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-12 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-13 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-14 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-15 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-16 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-17 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-18 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-19 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-20 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-21 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-22 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-23 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-24 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-25 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-26 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-27 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-28 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-29 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-06-30 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-07-01 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-07-02 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-07-03 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-07-04 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-07-05 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-07-06 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-07-07 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-07-08 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-07-09 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-07-10 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-07-11 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-07-12 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-07-13 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-07-14 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-07-15 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-07-16 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-07-17 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-07-18 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-07-19 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-07-20 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-07-21 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-07-22 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-07-23 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-07-24 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-07-25 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-07-26 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-07-27 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-07-28 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-07-29 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-07-30 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-07-31 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-01 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-02 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-03 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-04 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-05 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-06 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-07 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-08 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-09 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-10 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-11 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-12 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-13 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-14 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-15 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-16 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-17 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-18 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-19 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-20 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-21 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-22 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-23 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-24 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-25 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-26 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-27 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-28 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-08-29 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-08-30 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-08-31 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-09-01 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-02 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-09-03 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-09-04 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-09-05 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-06 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-07 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-08 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-09 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-10 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-11 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-12 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-13 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-14 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-15 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-16 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-17 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-18 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-19 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-20 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-21 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-22 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-23 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-24 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-25 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-26 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-27 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-28 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-29 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-09-30 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-10-01 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-10-02 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-10-03 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-10-04 00:00:00: Gumbel Copula with AIC=-133832314806.09
# Window ending at 2021-10-05 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-06 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-07 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-08 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-09 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-10-10 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-10-11 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-10-12 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-10-13 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-10-14 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-15 00:00:00: Gaussian Copula with AIC=-133832314806.09
# Window ending at 2021-10-16 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-17 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-18 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-19 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-20 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-21 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-22 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-23 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-24 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-25 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-26 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-27 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-28 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-29 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-30 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-10-31 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-01 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-02 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-03 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-04 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-05 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-06 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-07 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-08 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-09 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-10 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-11 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-12 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-13 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-14 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-15 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-16 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-17 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-18 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-19 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-20 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-21 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-11-22 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-11-23 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-11-24 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-11-25 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-11-26 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-11-27 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-11-28 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-11-29 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-11-30 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-12-01 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-12-02 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-12-03 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-12-04 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-12-05 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-12-06 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-12-07 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-12-08 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-12-09 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-12-10 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-12-11 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-12-12 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-12-13 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-12-14 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-12-15 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-12-16 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-12-17 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-12-18 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-12-19 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-12-20 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2021-12-21 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-12-22 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-12-23 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-12-24 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-12-25 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-12-26 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-12-27 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-12-28 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-12-29 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-12-30 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2021-12-31 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-01-01 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-01-02 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-01-03 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-01-04 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-01-05 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-01-06 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-01-07 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-01-08 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-01-09 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-01-10 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-01-11 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-01-12 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-01-13 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-01-14 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-01-15 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-01-16 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2022-01-17 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2022-01-18 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2022-01-19 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2022-01-20 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2022-01-21 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2022-01-22 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2022-01-23 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2022-01-24 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2022-01-25 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2022-01-26 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2022-01-27 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2022-01-28 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2022-01-29 00:00:00: Clayton Copula with AIC=-133832314806.09
# Window ending at 2022-01-30 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-01-31 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-02-01 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-02-02 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-02-03 00:00:00: Student-t Copula with AIC=-133832314806.09
# Window ending at 2022-02-04 00:00:00: Student-t Copula with AIC=-133832314806.09

# %%
###############################################################################
# 5) FIT A STUDENT-T COPULA USING COPULAE ON THE FINAL STANDARDIZED RESIDUALS
###############################################################################

# Gather final standardized residuals from the last chosen model
final_std_resids = pd.DataFrame(index=df_returns.index, columns=df_returns.columns)
for asset in assets:
    best_fit = chosen_models.get((asset, last_day_idx), None)
    if best_fit is not None:
        final_std_resids[asset] = best_fit.resid / best_fit.conditional_volatility

final_std_resids = final_std_resids.dropna()

# Convert to [0,1] (pseudo-observations)
u_data = final_std_resids.apply(lambda col: to_uniform(col), axis=0).dropna()

# Fit a Student-t Copula
copula = StudentCopula(dim=u_data.shape[1])
copula.fit(u_data.values)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[112], line 19
#      17 # Fit a Student-t Copula
#      18 copula = StudentCopula(dim=u_data.shape[1])
# ---> 19 copula.fit(u_data.values)
#
# File c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\copulae\elliptical\student.py:115, in StudentCopula.fit(self, data, x0, method, optim_options, ties, verbose, to_pobs, scale, fix_df)
#     112         optim_options = {'constraints': []}
#     113     optim_options['constraints'].append({'type': 'eq', 'fun': lambda x: x[0] - self._df})  # df doesn't change
# --> 115 return super().fit(data, x0, method, optim_options, ties, verbose, to_pobs, scale)
#
# File c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\copulae\copula\base.py:134, in BaseCopula.fit(self, data, x0, method, optim_options, ties, verbose, to_pobs, scale)
#     130     raise InputDataError('Input data must be between [0, 1] (marginals). Set to_pobs=True if you want '
#     131                          'copulae to convert this automatically for you')
#     133 x0 = np.asarray(x0) if x0 is not None and not isinstance(x0, np.ndarray) and isinstance(x0, Collection) else x0
# --> 134 self._fit_smry = fit_copula(self, data, x0, method, verbose, optim_options, scale)
#     136 if isinstance(data, pd.DataFrame):
#     137     self._columns = list(data.columns)
#
# File c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\copulae\copula\estimator\estimator.py:98, in fit_copula(copula, data, x0, method, verbose, optim_options, scale)
#      96 if m in {'ml'}:
#      97     x0 = initial_params(copula, data, x0)
# ---> 98     return estimate_max_likelihood_params(copula, data, x0, options, verbose, scale)
#      99 elif m in ('itau', 'irho'):
#     100     return estimate_corr_inverse_params(copula, data, m)
#
# File c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\copulae\copula\estimator\max_likelihood.py:59, in estimate_max_likelihood_params(copula, data, x0, optim_options, verbose, scale)
#      56     except ValueError:  # error encountered when setting invalid parameters
#      57         return np.inf
# ---> 59 res: OptimizeResult = minimize(calc_log_lik, x0, **optim_options)
#      60 if not res['success']:
#      61     if verbose >= 1:
#
# File c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\scipy\optimize\_minimize.py:722, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     719     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     720                            bounds=bounds, **options)
#     721 elif meth == 'slsqp':
# --> 722     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     723                           constraints, callback=callback, **options)
#     724 elif meth == 'trust-constr':
#     725     res = _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     726                                        bounds, constraints,
#     727                                        callback=callback, **options)
#
# File c:\Users\marko\anaconda3\envs\rllib-torch\lib\site-packages\scipy\optimize\_slsqp_py.py:353, in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, **unknown_options)
#     350 len_w = (3*n1+m)*(n1+1)+(n1-meq+1)*(mineq+2) + 2*mineq+(n1+mineq)*(n1-meq) \
#     351         + 2*meq + n1 + ((n+1)*n)//2 + 2*m + 3*n + 3*n1 + 1
#     352 len_jw = mineq
# --> 353 w = zeros(len_w)
#     354 jw = zeros(len_jw)
#     356 # Decompose bounds into xl and xu
#
# KeyboardInterrupt:

# %%
###############################################################################
# 6) NEXT-DAY COVARIANCE FORECAST
###############################################################################

# Gather final forecasted volatilities for each asset
final_vols = []
for asset in assets:
    vol_val = vol_forecasts.loc[df_returns.index[last_day_idx], asset]
    # Fallback to historical standard deviation if forecast is missing
    if pd.isna(vol_val):
        vol_val = df_returns[asset].std()
    final_vols.append(vol_val)
final_vols = np.array(final_vols)

# Extract the correlation matrix from the fitted copula
copula_corr = copula.sigma

# Number of assets
n_assets = len(assets)

# Construct the forecasted covariance matrix
cov_forecast = np.zeros((n_assets, n_assets))
for i in range(n_assets):
    for j in range(n_assets):
        cov_forecast[i, j] = final_vols[i] * final_vols[j] * copula_corr[i, j]

# Convert to DataFrame for better readability
cov_forecast_df = pd.DataFrame(cov_forecast, index=assets, columns=assets)

# Display the forecasted covariance matrix
print("\n--- Next-Day Forecasted Covariance Matrix (Copula-GARCH) ---")
print(cov_forecast_df)
# Out:
# --- Next-Day Forecasted Covariance Matrix (Copula-GARCH) ---
#                Tron    Solana  Avalanche       Xrp        Bnb    Bitcoin  \
# Tron       0.034395  0.030008   0.040281  0.029656   0.224553   0.253639
# Solana     0.030008  0.192094   0.197769  0.109479   0.874951   1.048084
# Avalanche  0.040281  0.197769   0.342357  0.148943   1.189647   1.344949
# Xrp        0.029656  0.109479   0.148943  0.167503   0.766701   0.857114
# Bnb        0.224553  0.874951   1.189647  0.766701  11.935785   7.634084
# Bitcoin    0.253639  1.048084   1.344949  0.857114   7.634084  10.748240
# Doge       0.032388  0.144290   0.199109  0.128632   1.031704   1.168511
# Etherium   0.322170  1.236132   1.609053  1.036600   9.340192  10.620747
# PolkaDot   0.039279  0.156784   0.227855  0.134241   1.053903   1.122828
#
#                Doge   Etherium  PolkaDot
# Tron       0.032388   0.322170  0.039279
# Solana     0.144290   1.236132  0.156784
# Avalanche  0.199109   1.609053  0.227855
# Xrp        0.128632   1.036600  0.134241
# Bnb        1.031704   9.340192  1.053903
# Bitcoin    1.168511  10.620747  1.122828
# Doge       0.233626   1.352931  0.174139
# Etherium   1.352931  15.845537  1.429330
# PolkaDot   0.174139   1.429330  0.241512

# %%
###############################################################################
# 7) SCENARIO GENERATION
###############################################################################

num_scenarios = 5000

# 7a) Sample from the Student Copula in U-space
u_sim = copula.random(num_scenarios)  # shape: (5000, n_assets)

# 7b) Invert each dimension using the final chosen distribution from GARCH
simulated_returns = np.zeros((num_scenarios, n_assets))

for i, asset in enumerate(assets):
    best_fit = chosen_models.get((asset, last_day_idx), None)
    if best_fit is None:
        dist_name = 'normal'
        dof = 8.0
    else:
        dist_name = best_fit.distribution.name.lower()
        # Attempt to get dof from GARCH param
        dof = best_fit.params.get('nu', 8.0)

    vol_i = final_vols[i]
    u_col = u_sim[:, i]

    if 'student' in dist_name:
        z = t.ppf(u_col, df=dof)  # Student's t(\u03bd)
    elif 'normal' in dist_name:
        z = norm.ppf(u_col)       # standard normal
    elif 'skewt' in dist_name:
        # approximate skew-t by t
        z = t.ppf(u_col, df=dof)
    else:
        z = norm.ppf(u_col)
    
    simulated_returns[:, i] = z * vol_i

simulated_returns_df = pd.DataFrame(simulated_returns, columns=assets)
print("\nSimulated scenario returns (first 5 rows):")
print(simulated_returns_df.head())

print("\nFinished! Steps performed:")
print("1) Loaded prices from CSV, computed daily returns.")
print("2) Rolling GARCH(1,1) fit with distribution selection (normal, t, skewt).")
print("3) Fitted Student-t Copula (copulae) on standardized residuals.")
print("4) Constructed next-day covariance matrix (Copula correlation * GARCH vol).")
print("5) Generated scenario returns by sampling from the Student Copula.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 19
#      17     dof = 8.0
#      18 else:
# ---> 19     dist_name = best_fit.distribution.name.lower()
#      20     # Attempt to get dof from GARCH param
#      21     dof = best_fit.params.get('nu', 8.0)
#
# AttributeError: 'ARCHModelResult' object has no attribute 'distribution'
